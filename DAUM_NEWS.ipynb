# %%
# https://news.v.daum.net/v/20200605102016392
# https://news.v.daum.net/v/20200605110456504

# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
#     font-size: 14px;
#     font-family: Bitstream vera sans mono;
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
#     font-size: 14px;
#     font-family: Bitstream vera sans mono;
# </style>

# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_daum_news_title(news_id):
    url = 'https://news.v.daum.net/v/{}'.format(news_id)
    response = requests.get(url)
    status_code = response.status_code
    if status_code == 200:
        soup = BeautifulSoup(response.text)
        title_h3 = soup.select_one('h3.tit_view')
        ret_title = title_h3.text.replace("\'",'').replace('"','')
    else:
        soup = 'status_code:{}'.format(status_code)
    return ret_title

# %%
# url = 'https://news.v.daum.net/v/{}'.format('20200605110456504')
# response = requests.get(url)
# response.status_code
# soup = BeautifulSoup(response.text)
# content = soup.select('div#harmonyContainer')
# for p in content:
#     print(p.text)

# %%
daum_news_title = get_daum_news_title('20200605110456504')
print(daum_news_title)
# Out:
# 미국, 흑인들에겐 단 한 번도 위대한 나라 아니었다

# %%
def get_daum_news_content(news_id):
    url = 'https://news.v.daum.net/v/{}'.format(news_id)
    response = requests.get(url)
    status_code = response.status_code
    ret_content=''
    if status_code == 200:
        soup = BeautifulSoup(response.text)
        content = soup.select('div#harmonyContainer')
        for p in content:
            ret_content += p.text
        ret_content = title_h3.text.replace("\'",'').replace('"','')
    else:
        soup = 'status_code:{}'.format(status_code)
    return ret_content

# %% [markdown]
# ## 댓글가져오기

# %%
news_id = '20200605114023995'
url = 'https://news.v.daum.net/v/{}'.format(news_id)
response = requests.get(url)
soup = BeautifulSoup(response.text)
soup

# %%
list_comment = soup.select_one('ul.list_comment')
print(list_comment)
# Out:
# None

# %%
#https://comment.daum.net/apis/v1/posts/@20200605114023995/comments
#    ?parentId=0&offset=0&limit=3&sort=RECOMMEND&isInitial=true

# %%
news_id = '20200605114023995'
url = 'https://comment.daum.net/apis/v1/posts/@{}/comments'.format(news_id)
params={'parentId':0,'offset':0,'limit':10,'sort':'RECOMMEND','isInitial':'true'}
headers = {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..rofgslwMjfqlkSC-H5b2hmIo02YgjFGbXL98rshGR4U'}
## 401 -> header 추가
response = requests.get(url,headers = headers, params=params)
status_code = response.status_code 
comment_all = response.json()



for item in comment_all:
    print(item['content'].replace('\n',''))
    print()

# %% [markdown]
# ## 다음뉴스 댓글갯수 가져오기

# %%
news_id='20200605114023995'
url = 'https://comment.daum.net/apis/v1/posts/@{}'.format(news_id)
headers={'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..rofgslwMjfqlkSC-H5b2hmIo02YgjFGbXL98rshGR4U'}
response = requests.get(url, headers=headers)
comment_count = response.json()['commentCount']
print(comment_count)
# Out:
# 228

# %%
## 강사님 풀이

url = 'https://news.v.daum.net/v/20200608095807496'

response = requests.get(url)
soup = BeautifulSoup(response.text)
count = soup.select_one('em.num_count')
print(count)


url='https://comment.daum.net/apis/v1/posts/@20200608095807496'
headers={'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..XJ7N_9t-amsYIrWpXHVIYuzyYMCjDFsHndvY47nvUUY'}
response = requests.get(url, headers=headers)

data = response.json()
commentdCount = data['commentCount']
commentdCount
# Out:
# None
# 30

# %% [markdown]
# ## 네이버뉴스 댓글갯수

# %%
url = 'https://news.naver.com/main/ranking/read.nhn'
params = {'mid':'etc','sid1':'111','rankingType':'popular_day','oid':'016','aid':'0001682739','date':'20200605','type':'1','rankingSeq':'1','rankingSectionId':'102'}

headers={'accept': '*/*'}
 
response = requests.get(url,headers = headers, params=params)
response.text
soup = BeautifulSoup(response.text)
soup
#print(soup.select_one('div.u_cbox_wrap u_cbox_ko u_cbox_type_sort_favorite'))
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="width=1106" name="viewport"/>
# <title>[속보] ‘관악 리치웨이’ 확진자 11명 추가…서울 신규 확진 20명 : 네이버 뉴스</title>
# <meta content="헤럴드경제 : 네이버뉴스" property="me2:post_tag"/>
# <meta content="헤럴드경제" property="me2:category1"/>
# <meta content="기타 기사" property="me2:category2"/>
# <meta content="https://imgnews.pstatic.net/image/016/2020/06/05/20200605000328_0_20200605113802364.jpg" property="me2:image"/>
# <meta content="[속보] ‘관악 리치웨이’ 확진자 11명 추가…서울 신규 확진 20명" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;oid=016&amp;aid=0001682739&amp;sid1=001" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/016/2020/06/05/20200605000328_0_20200605113802364.jpg" property="og:image"/>
# ...

# %% [markdown]
# ## 삼성전자-financial summary

# %%
url = 'https://navercomp.wisereport.co.kr/v2/company/ajax/cF1001.aspx'
parmas = {'cmp_cd':'005930','fin_typ':'0','freq_typ':'A','encparam':'aUl4bm82VjZNSWY4MTJ1K29KMnJNQT09','id':'QmZIZ20rMn'}
header = {'Accept': '*/*', 'q':'0.01'}
response = requests.get(url,headers=header, params=params)
data = response.text
    
soup = BeautifulSoup(data)
print(soup)
